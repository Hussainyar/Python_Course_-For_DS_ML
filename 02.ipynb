# %% [markdown]
# <a href="https://colab.research.google.com/github/Hussainyar/Python_Course_-For_DS_ML/blob/main/02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!-- Slide 1: What is a Variable? -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Variables in Python
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **What is a Variable?**
# - A container that stores information
# - Like a labeled box holding data
# - You can create, read, and change variables
#
# **Creating Variables**
# - Use a name and assign a value with =
# - Example: `name = "Ahmed"` or `age = 25`
# - Names should be meaningful and simple
#
# **Variable Naming Rules**
# - Start with a letter or underscore (_)
# - Use letters, numbers, and underscores only
# - No spaces or special characters
# - Good names: `my_name`, `student_age`, `total_score`
# </div>
# </div>
#
# <!-- Slide 2: Data Types in Python -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Data Types in Python
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **String (str)** - Text data
# - `name = "Ahmed"`
# - `city = "Hamburg"`
#
# **Integer (int)** - Whole numbers
# - `age = 25`
# - `score = 100`
#
# **Float (float)** - Decimal numbers
# - `height = 1.75`
# - `temperature = 23.5`
#
# **Boolean (bool)** - True or False
# - `is_student = True`
# - `is_online = False`
#
# Python automatically knows the data type!
# </div>
# </div>
#
# <!-- Slide 3: Working with Strings -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Working with Strings
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Combining Strings**
# - `first_name = "Ahmed"`
# - `last_name = "Khan"`
# - `full_name = first_name + " " + last_name`
#
# **String Length**
# - `text = "Python"`
# - `length = len(text)` → 6
#
# **Changing Case**
# - `text.upper()` → "PYTHON"
# - `text.lower()` → "python"
#
# **Finding Characters**
# - `text[0]` → "P" (first character)
# - `text[1]` → "y" (second character)
# </div>
# </div>
#
# <!-- Slide 4: Math Operations -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Math Operations
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Basic Math**
# - Addition: `5 + 3` → 8
# - Subtraction: `10 - 2` → 8
# - Multiplication: `4 * 5` → 20
# - Division: `20 / 4` → 5.0
#
# **Using Variables**
# - `age = 25`
# - `next_year = age + 1` → 26
# - `double_age = age * 2` → 50
#
# **Order of Operations**
# - `2 + 3 * 4` → 14 (multiplication first)
# - `(2 + 3) * 4` → 20 (parentheses first)
# </div>
# </div>
#
# <!-- Slide 5: Updating Variables -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Updating Variables
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Changing a Value**
# - `score = 80`
# - `score = 90` (old value replaced)
# - Variable now holds 90
#
# **Quick Update**
# - `score = score + 10` (add 10 to current value)
# - `score += 10` (same thing, shorter way)
# - `score -= 5` (subtract 5)
#
# **Swapping Values**
# - `a = 5`
# - `b = 10`
# - `a, b = b, a` (swap them)
# - Now: a = 10, b = 5
#
# Variables are flexible and can change anytime!
# </div>
# </div>
#
# <!-- Slide 6: Practice Example -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Practice: Student Profile
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **Create These Variables:**
# - `student_name = "Fatima"`
# - `student_age = 20`
# - `gpa = 3.8`
# - `is_active = True`
#
# **Try These Operations:**
# - `print(student_name)`
# - `print("Age:", student_age)`
# - `future_age = student_age + 5`
# - `print(future_age)`
#
# **Combine Multiple Variables:**
# - `info = student_name + " is " + str(student_age)`
# - `print(info)` → "Fatima is 20"
#
# Try typing this code yourself!
# </div>
# </div>
#
# <!-- Slide 7: Summary & Next Steps -->
# <div style="width: 100%; max-width: 1000px; margin: 30px auto; background: white; box-shadow: 0 10px 40px rgba(0,0,0,0.1); border-radius: 12px; overflow: hidden;">
# <div style="background: white; color: #38bdf8; padding: 30px 40px; text-align: center; font-size: 2.2em; font-weight: bold; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; border-bottom: 3px solid #38bdf8;">
# Summary & What's Next
# </div>
# <div style="padding: 40px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; font-size: 1.1em; line-height: 1.8; color: #333;">
#
# **What You Learned:**
# - Variables store data with meaningful names
# - Four main data types: String, Integer, Float, Boolean
# - Follow naming rules: start with letter/underscore, use letters/numbers only
# - Variables can be changed and updated anytime
#
# **Practice:**
# - Create variables for yourself
# - Try combining strings and numbers
# - Use math operations on your variables
#
# **Next Lecture:**
# - Input & Output (Getting data from users)
# - Lists and Tuples (Store multiple values)
# - Getting hands-on with code!
#
# Keep practicing! 🚀
# </div>
# </div>
